# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %%
x_total, y_total =  make_regression(n_samples=20, n_features=1, n_targets=1, noise=1)
plt.scatter(x_total, y_total)
plt.show()

# %%
rezultat = train_test_split(x_total, y_total, train_size=0.8)
print(type(rezultat), len(rezultat))
for i in range(4):
    print(type(rezultat[i]), len(rezultat[i]))
# Out:
# <class 'list'> 4
# <class 'numpy.ndarray'> 16
# <class 'numpy.ndarray'> 4
# <class 'numpy.ndarray'> 16
# <class 'numpy.ndarray'> 4

# %%
x_train, x_test, y_train, y_test = rezultat

# %%
plt.scatter(x_train, y_train)
plt.show()

# %%
plt.scatter(x_test, y_test)
plt.show()

# %%
# 80% / 20%  -> 16 4 

# x_train = x_total[:16] # primele 16
# y_train = y_total[:16] # primele 16

# x_test = x_total[16:] # ultimele 4 (daca sunt 20 in total)
# y_test = y_total[16:] # ultimele 4 (daca sunt 20 in total)

# %%
KNN_options = range(2, 11)

score_dict = {

}

for option in KNN_options:
    knn_model = KNeighborsRegressor(n_neighbors=option)
    knn_model.fit(x_train, y_train)
    score = knn_model.score(x_test, y_test)
    score_dict[option] = score

print(score_dict)
# Out:
# {2: 0.9789679032684941, 3: 0.9527196351927513, 4: 0.9411167880225699, 5: 0.8899628049609865, 6: 0.8385072488090081, 7: 0.7913026207358158, 8: 0.7574164673120973, 9: 0.6848518372156881, 10: 0.5981997129889386}
