# %%
# pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
rezultat = make_regression(n_samples=3, n_features=1, n_targets=1)
print(rezultat, type(rezultat))
# Out:
# (array([[-0.5933276 ],
#        [-0.36285314],
#        [-0.96541226]]), array([ -9.98409831,  -6.1058366 , -16.24527639])) <class 'tuple'>

# %%
x, y = rezultat

# %%
# [-0.45191199, -0.04657521, -0.00700557] # scipy
# [[-0.45191199],[-0.04657521],[-0.00700557]] # sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
x, y = make_regression(n_samples=3, n_features=1, n_targets=1)
model.fit(x, y)
# Out:
# LinearRegression()

# %%
x, y
# Out:
# (array([[-0.60039563],
#         [ 0.93084262],
#         [ 0.73510245]]),
#  array([-40.20896638,  62.3392606 ,  49.23038792]))

# %%
model.predict([[ 0.05546252]])
# Out:
# array([3.71436849])

# %%
model.predict([[ 0.05546252], [-0.86250025]])
# Out:
# array([  3.71436849, -57.7623186 ])

# %%
plt.scatter(x, y)
plt.show()

# %%
new_x, new_y =  make_regression(n_samples=20, n_features=1, n_targets=1)
plt.scatter(new_x, new_y)
plt.show()

# %%
new_x, new_y =  make_regression(n_samples=20, n_features=1, n_targets=1, noise=10)
plt.scatter(new_x, new_y)
plt.show()

# %%
new_model = LinearRegression()
new_model.fit(new_x, new_y)
# Out:
# LinearRegression()

# %%
predicted_y = new_model.predict(new_x)

# %%
plt.scatter(new_x, new_y)
plt.plot(new_x, predicted_y)
plt.show()

# %%
real_vs_prezis = {"y_real":new_y, "y_prezis":predicted_y}
df_real_vs_prezis = pd.DataFrame(real_vs_prezis)
df_real_vs_prezis
# Out:
#        y_real   y_prezis
# 0   -2.516418   6.614453
# 1   10.785245   9.157432
# 2   -1.529814   5.301362
# 3  -10.522010   3.814132
# 4   15.291552   5.983345
# 5    3.069084   6.923141
# 6   11.364260   1.371001
# 7   14.323854  11.029224
# 8    2.110960  -3.381094
# 9    6.447404   1.897683
# 10  23.324783   6.706859
# 11   0.435051   7.844646
# 12  -5.304854   3.135312
# 13 -10.171065   3.955517
# 14  15.605801   8.773678
# 15  10.325223   2.661954
# 16   4.158328   4.283816
# 17   4.378601   4.552575
# 18  15.732012  10.623993
# 19   0.047554   6.106520
